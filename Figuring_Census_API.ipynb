# %%
pip install census
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\tyms1\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
pip install us
# Out:
# ...
#   Using cached us-2.0.2.tar.gz (14 kB)
# ...
#   Using cached jellyfish-0.6.1.tar.gz (132 kB)
# ...
#   Created wheel for us: filename=us-2.0.2-py3-none-any.whl size=11931 sha256=7d2f3793a1f5ff5fa9516897ad2a3c787b24336678442b1c6e5e7b1751c2f841
#   Stored in directory: c:\users\tyms1\appdata\local\pip\cache\wheels\ca\6b\11\cda9ea2438f721330a35c9a2c8e34b4aedcd34c89af48a4d00
# ...
#   Created wheel for jellyfish: filename=jellyfish-0.6.1-py3-none-any.whl size=10386 sha256=ae885dafc8da2dceb6e0a9979f89086b2d7de9c91c387d8a66aa4871eb0d0e53
#   Stored in directory: c:\users\tyms1\appdata\local\pip\cache\wheels\a1\99\51\7de469e37cd1b3c763c24394e1ebf1baa2d79e094bf346cf80
# Successfully built us jellyfish
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\tyms1\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from census import Census
from us import states

# %%
# API KEY
key = "dd555fb3896d61afdb4f07fbb6beaa747cc7d2ef"
c = Census(key)

# %%
#url ="https://api.census.gov/data/2019/acs/acs1?get=NAME&for=us:1&key="

# %%
#response = requests.get(url+key)

# %%
#print(response)

# %%
c.acs5.state(('B02015_012E'), states.CA.fips, year=2019)
# Out:
# [{'B02015_012E': 464242.0, 'state': '06'}]

# %%
c.acs5.tables()
# Out:
# [{'name': 'B17015',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY SOCIAL SECURITY INCOME BY SUPPLEMENTAL SECURITY INCOME (SSI) AND CASH PUBLIC ASSISTANCE INCOME',
#   'variables': 'https://api.census.gov/data/2018/acs/acs5/groups/B17015.json'},
#  {'name': 'B18104',
#   'description': 'SEX BY AGE BY COGNITIVE DIFFICULTY',
#   'variables': 'https://api.census.gov/data/2018/acs/acs5/groups/B18104.json'},
#  {'name': 'B17016',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY WORK EXPERIENCE OF HOUSEHOLDER AND SPOUSE',
#   'variables': 'https://api.census.gov/data/2018/acs/acs5/groups/B17016.json'},
#  {'name': 'B18105',
#   'description': 'SEX BY AGE BY AMBULATORY DIFFICULTY',
#   'variables': 'https://api.census.gov/data/2018/acs/acs5/groups/B18105.json'},
#  {'name': 'B17017',
#   'description': 'POVERTY STATUS IN THE PAST 12 MONTHS BY HOUSEHOLD TYPE BY AGE OF HOUSEHOLDER',
# ...

# %%
c.acs5.get('NAME', geo={'for': 'tract:*',
                       'in': 'state:{} county:1'.format(states.CA.fips)})
# Out:
# []

# %%
c.acs5.state_county_tract('NAME', states.CA.fips, '170', Census.ALL)
# Out:
# []

# %%
c.acs5.state(('NAME', 'B25034_010E'), states.MD.fips)
# Out:
# [{'NAME': 'Maryland', 'B25034_010E': 129309.0, 'state': '24'}]

# %%
#state_county_tract(fields, state_fips, county_fips, tract) 06 = California, 037 = Los Angeles County
ac5_tract_date = c.acs5.state_county_tract('B02015_012E', '06' , '037', Census.ALL, year = 2019)

# %%
df = pd.DataFrame (data = ac5_tract_date)

# %%
df = df.rename(columns={"B02015_012E": "Korean Population"})

# %%
df
# Out:
#       Korean Population state county   tract
# 0                  20.0    06    037  482702
# 1                  91.0    06    037  500201
# 2                  34.0    06    037  500202
# 3                   0.0    06    037  500300
# 4                   0.0    06    037  500500
# ...                 ...   ...    ...     ...
# 2341                8.0    06    037  104108
# 2342                0.0    06    037  104203
# 2343                9.0    06    037  104204
# 2344                0.0    06    037  104403
# 2345                0.0    06    037  104404
#
# [2346 rows x 4 columns]

# %%
c.acs5.state_county_tract('B02015_012E', '06' , '037', '211803', year = 2019)
# Out:
# [{'B02015_012E': 1692.0, 'state': '06', 'county': '037', 'tract': '211803'}]

# %%
c.acs5.state(('NAME', 'B02015_012E'), states.MD.fips)
# Out:
# [{'NAME': 'Maryland', 'B02015_012E': 48530.0, 'state': '24'}]

# %%
sf1_get= c.sf1.get('NAME', geo={'for': 'tract:*',
                       'in': 'state:{} county:037'.format(states.CA.fips)})

# %%
sf1_get[0]['tract']
# Out:
# '101110'

# %%
b = {'Name': "Census", "state":"06"}
b
# Out:
# {'Name': 'Census', 'state': '06'}

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
tract_list = []

# %%
for tr in sf1_get:
   print(tr['tract'])
# Out:
# 101110
# 101122
# 101210
# 101220
# 101300
# 101400
# 102103
# 102104
# 102105
# 102107
# 103101
# 103102
# 103200
# 103300
# 103400
# 104103
# 104105
# 104108
# 104124
# 104201
# 104203
# 104204
# 104310
# 104320
# 104403
# 104404
# 104500
# 104701
# 104703
# 104704
# 104810
# 104821
# 104822
# 106010
# 106020
# 104401
# 104610
# 104620
# 106111
# 106112
# 106113
# 106114
# 106403
# 106405
# 106406
# 106407
# 106408
# 106510
# 106520
# 106641
# 106643
# 106645
# 106646
# 106648
# 106649
# 107010
# 107020
# 108101
# 106603
# 106604
# 106642
# 108102
# 108103
# 108104
# 108201
# 108202
# 109100
# 109200
# 109601
# 109300
# 109400
# 109500
# 109603
# 109604
# 109700
# 109800
# 111100
# 111201
# 111202
# 111204
# 111205
# 111206
# 111301
# 111302
# 111400
# 113101
# 113102
# 113211
# 113212
# 113231
# 113233
# 113237
# 113303
# 113213
# 113235
# 113232
# 113234
# 113301
# 113321
# 113322
# 113401
# 113421
# 113422
# 115101
# 115103
# 115104
# 115201
# 115202
# 115301
# 115302
# 115401
# ...

# %%
c.state_county_tract(fields, state_fips, county_fips, tract)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-b4a826626695> in <module>
# ----> 1 c.state_county_tract(fields, state_fips, county_fips, tract)
#
# AttributeError: 'Census' object has no attribute 'state_county_tract'

# %%
#3가지 버젼
